# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading the dataset
df = pd.read_csv("car data.csv")

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Selling_type Transmission  Owner
# 0       Dealer       Manual      0
# 1       Dealer       Manual      0
# 2       Dealer       Manual      0
# 3       Dealer       Manual      0
# 4       Dealer       Manual      0

# %%
#some basic information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Driven_kms     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Selling_type   301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
#descriptive statistics
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Driven_kms       Owner
# count   299.000000     299.000000     299.000000     299.000000  299.000000
# mean   2013.615385       4.589632       7.541037   36916.752508    0.043478
# std       2.896868       4.984240       8.566332   39015.170352    0.248720
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.850000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.510000       6.100000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.840000   48883.500000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
#cheking missing values
df.isna().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Driven_kms       0
# Fuel_Type        0
# Selling_type     0
# Transmission     0
# Owner            0
# dtype: int64

# %%
#checking duplicate values
df.duplicated().sum()
# Out:
# 2

# %%
df.drop_duplicates(inplace=True)

# %%
#checking duplicate values
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Visualization of Data

# %%
plt.figure(figsize=(10,6))
sns.countplot(y="Fuel_Type",data=df,palette="Set1")
plt.show()
# Out:
# C:\Users\Bidisha Shit\AppData\Local\Temp\ipykernel_5552\2350986081.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y="Fuel_Type",data=df,palette="Set1")

# %%
plt.figure(figsize=(10,6))
sns.countplot(y="Selling_type",data=df,palette="Set1")
plt.show()
# Out:
# C:\Users\Bidisha Shit\AppData\Local\Temp\ipykernel_5552\60645895.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y="Selling_type",data=df,palette="Set1")

# %%
plt.figure(figsize=(10,6))
sns.countplot(y="Transmission",data=df,palette="Set1")
plt.show()
# Out:
# C:\Users\Bidisha Shit\AppData\Local\Temp\ipykernel_5552\1766350315.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y="Transmission",data=df,palette="Set1")

# %%
plt.figure(figsize=(10,6))
sns.countplot(y="Owner",data=df,palette="Set1")
plt.ylabel("No of Owner")
plt.show()
# Out:
# C:\Users\Bidisha Shit\AppData\Local\Temp\ipykernel_5552\3025434195.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y="Owner",data=df,palette="Set1")

# %%
plt.figure(figsize=(15,7))
for i,col in enumerate(['Selling_Price','Present_Price','Driven_kms']):
    plt.subplot(2,2,i+1)
    sns.histplot(data=df, x=col, kde=True, hue='Transmission')

# %% [markdown]
# Automatic Cars seem to have higher both Present_Price and Selling_Price, and higher Driven_kms as well than Manual Cars.

# %%
plt.figure(figsize=(18,9))
for i,col in enumerate(['Selling_Price','Present_Price','Driven_kms']):
    plt.subplot(2,2,i+1)
    sns.boxplot(data=df, y='Fuel_Type', x=col, orient='h')

# %% [markdown]
# Diesel Cars seem to have higher price than others, while Petrol Cars seem to have higher price than CNG cars.Data seems to contain a lot of outliers and need to be scaled as well.

# %%
plt.figure(figsize=(20,8))
for i,col in enumerate(['Selling_Price','Present_Price']):
    plt.subplot(2,2,i+1)
    sns.boxplot(data=df, y='Transmission', x=col, orient='h')

# %%
plt.figure(figsize=(17,8))
for i,col in enumerate(['Selling_Price','Present_Price','Driven_kms']):
    plt.subplot(2,2,i+1)
    sns.boxplot(data=df, y='Selling_type', x=col, orient='h')

# %% [markdown]
# Dealer seems to sell the car at higher Selling_Price than Individual.

# %%
plt.figure(figsize=(15,8))
color=['brown','purple','pink']
for i,col in enumerate(['Year','Present_Price','Driven_kms']):
    plt.subplot(2,2,i+1)
    sns.scatterplot(df,x=col,y='Selling_Price',color=color[i])
plt.tight_layout()

# %% [markdown]
# Latest cars seem to have higher selling price.
# Greatest is the present price, greater is the selling price.
# Less is the driven kms, more is the selling price.

# %%
#remove outliers of the data
def remove_outliers(col):
    d25=df[col].quantile(0.25)
    d75=df[col].quantile(0.75)
    diqr=d75-d25
    upper_lim=d75+1.5*diqr
    lower_lim=d25-1.5*diqr
    filter_data=df[ (df[col] >= lower_lim) & (df[col] <= upper_lim) ]
    return filter_data

data=remove_outliers('Selling_Price')
data=remove_outliers('Present_Price')
data=remove_outliers('Driven_kms')

# %% [markdown]
# 'Fuel_Type','Selling_type','Transmission','Car_Name' are object type . Categorical data type is not appropriate for machine learning models,so we will apply label encoder

# %%
from sklearn.preprocessing import LabelEncoder

#hot encoding
encoder=LabelEncoder()

encoder.fit(df['Fuel_Type'])
df['Fuel_Type']=encoder.fit_transform(df['Fuel_Type'])
dictft=dict(enumerate(encoder.classes_))
#print(dictft)

encoder.fit(df['Selling_type'])
df['Selling_type']=encoder.fit_transform(df['Selling_type'])
dictst=dict(enumerate(encoder.classes_))
#print(dictst)

encoder.fit(df['Transmission'])
df['Transmission']=encoder.fit_transform(df['Transmission'])
dicttr=dict(enumerate(encoder.classes_))
#print(dicttr)

encoder.fit(df['Car_Name'])
df['Car_Name']=encoder.fit_transform(df['Car_Name'])
dictcn=dict(enumerate(encoder.classes_))
#print(dictcn)
df.head()
# Out:
#    Car_Name  Year  Selling_Price  Present_Price  Driven_kms  Fuel_Type  \
# 0        86  2014           3.35           5.59       27000          2
# 1        89  2013           4.75           9.54       43000          1
# 2        66  2017           7.25           9.85        6900          2
# 3        92  2011           2.85           4.15        5200          2
# 4        88  2014           4.60           6.87       42450          1
#
#    Selling_type  Transmission  Owner
# 0             0             1      0
# 1             0             1      0
# 2             0             1      0
# 3             0             1      0
# 4             0             1      0

# %%
X=df.drop(columns=['Selling_Price'],axis=1)
X=X.values
Y=df[['Selling_Price']].values.flatten()

X[:5,],Y[:5]
# Out:
# (array([[8.600e+01, 2.014e+03, 5.590e+00, 2.700e+04, 2.000e+00, 0.000e+00,
#          1.000e+00, 0.000e+00],
#         [8.900e+01, 2.013e+03, 9.540e+00, 4.300e+04, 1.000e+00, 0.000e+00,
#          1.000e+00, 0.000e+00],
#         [6.600e+01, 2.017e+03, 9.850e+00, 6.900e+03, 2.000e+00, 0.000e+00,
#          1.000e+00, 0.000e+00],
#         [9.200e+01, 2.011e+03, 4.150e+00, 5.200e+03, 2.000e+00, 0.000e+00,
#          1.000e+00, 0.000e+00],
#         [8.800e+01, 2.014e+03, 6.870e+00, 4.245e+04, 1.000e+00, 0.000e+00,
#          1.000e+00, 0.000e+00]]),
#  array([3.35, 4.75, 7.25, 2.85, 4.6 ]))

# %%
from sklearn.model_selection import train_test_split

# %%
#split data
x_train, x_test, y_train, y_test=train_test_split(X,Y,test_size=0.3,random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error,r2_score

# %%
mse_vals=[]
r2_vals=[]
min_mse=np.inf
max_r2=-np.inf
min_mse_n_est=None
max_r2_n_est=None

#from 1 decision tree to 100 decision trees
for i in range(1,101):
    rfr_model=RandomForestRegressor(n_estimators=i,random_state=42)
    rfr_model.fit(x_train, y_train)
    y_test_pred=rfr_model.predict(x_test)
    #MSE
    mse=mean_squared_error(y_test, y_test_pred)
    #R2 SCORE
    r2_sco=r2_score(y_test, y_test_pred)
    #append
    mse_vals.append(mse)
    r2_vals.append(r2_sco)
    #compare
    if mse<min_mse:
        min_mse=mse
        min_mse_n_est=i
    if r2_sco>max_r2:
        max_r2=r2_sco
        max_r2_n_est=i

print('Minimum MSE: {} with {}-estimators'.format(min_mse,min_mse_n_est))
print('Maximum R2 Score: {} with {}-estimators'.format(max_r2,max_r2_n_est))
# Out:
# Minimum MSE: 0.3587487913084846 with 33-estimators
# Maximum R2 Score: 0.9661355472028293 with 33-estimators

# %% [markdown]
# n_estimators=33 gives us the best value so we can use this specific value to train our model; however, its just a small difference in R2 Score, but good of approximately 0.3 difference in MSE

# %%
fig,ax=plt.subplots()
ax.plot(range(1,101),mse_vals,'red')
ax.set_xlabel('N-ESTIMATORS')
ax.set_ylabel('MSE')
ax2=ax.twinx()
ax2.plot(range(1,101),r2_vals,'green')
ax2.set_ylabel('R2 Score')
plt.title('N-Estimators vs MSE and R2 Score')
plt.show()

# %% [markdown]
# Model Development

# %%
#model development
rfr_model=RandomForestRegressor(n_estimators=33,random_state=42)
rfr_model.fit(x_train,y_train)
y_test_pred=rfr_model.predict(x_test)

#MSE
mse=mean_squared_error(y_test, y_test_pred)
print("Mean Squared Error: ",mse)

#R2 SCORE
r2_sco=r2_score(y_test, y_test_pred)
print("R2 Score: ",r2_sco)
# Out:
# Mean Squared Error:  0.3587487913084846
# R2 Score:  0.9661355472028293

# %% [markdown]
# Output vs Predicted

# %%
fig=plt.figure(figsize=(14,4))
sns.regplot(x=y_test,y=y_test_pred,color='purple')
plt.title('Actual vs Predicted Selling Price')
plt.xlabel('Actual Test Values')
plt.ylabel('Predicted Test Values')
# Out:
# Text(0, 0.5, 'Predicted Test Values')

# %% [markdown]
# THE MODEL RESULTS SEEM SATISFACTORY

# %% [markdown]
# IMPORTANCE OF FEATURES

# %%
feature_imps=pd.Series(rfr_model.feature_importances_,index=['Car_Name','Year','Present_Price','Driven_kms','Fuel_Type','Selling_type','Transmission','Owner'])
plt.figure(figsize=(10,8))
feature_imps.plot(kind='barh')
plt.ylabel('Features')
plt.xlabel('Importances')
plt.title('Feature Importances as per the Model/Random Forest Regressor')
plt.show()

# %% [markdown]
# Model - Decision Tree

# %%
dt_model=DecisionTreeRegressor(random_state=42)
dt_model.fit(x_train,y_train)
y_test_pred=dt_model.predict(x_test)

#MSE
mse=mean_squared_error(y_test, y_test_pred)
print("Mean Squared Error: ",mse)

#R2 SCORE
r2_sco=r2_score(y_test, y_test_pred)
print("R2 Score: ",r2_sco)
# Out:
# Mean Squared Error:  0.5091734939759035
# R2 Score:  0.9519360561761713

# %% [markdown]
# Therefore, our above choice Random Forest Regressor was perfect! As less MSE and more  R2
#   Score comparatively
